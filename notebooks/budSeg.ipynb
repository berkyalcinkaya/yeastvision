# %%
import tensorflow as tf
from matplotlib import pyplot as plt
from skimage.io import imread, imsave
from skimage.measure import label, regionprops, regionprops_table
import numpy as np
from cv2 import resize, merge

# %%
from models.utils import enlarge_bud, shrink_bud
from models.artilife.model import Artilife
from models.artilife.budSeg.model import BudSeg

# %%
weight_path = "models/artilife/artilife"
params = Artilife.hyperparams
params["Time Series"] = True
params
# Out:
# {'Mean Diameter': 0,
#  'Flow Threshold': 0.4,
#  'Cell Probability Threshold': 0,
#  'Mating Cells': False,
#  'Sporulating Cells': False,
#  'Time Series': True}

# %%
test_im = imread("test_images/test_phase.tif")[0:9,:,:]
plt.imshow(test_im[0,:,:]); plt.show()
plt.imshow(test_im[1,:,:]); plt.show()

# %%
output = Artilife.run(test_im, params, weight_path)
# Out:
# class params {'Mean Diameter': 0, 'Flow Threshold': 0.4, 'Cell Probability Threshold': 0, 'Mating Cells': False, 'Sporulating Cells': False, 'Time Series': True}
# 2023-01-02 14:40:32.212225: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Running Artilife
# (50, 50) (50, 50)
# 1/1 [==============================] - 1s 710ms/step
# (50, 50) (50, 50)
# 1/1 [==============================] - 0s 69ms/step
# (50, 50) (50, 50)
# 1/1 [==============================] - 0s 68ms/step
# (50, 50) (50, 50)
# 1/1 [==============================] - 0s 68ms/step
# (50, 50) (50, 50)
# 1/1 [==============================] - 0s 69ms/step
# (50, 50) (50, 50)
# 1/1 [==============================] - 0s 94ms/step
# (50, 50) (50, 50)
# ...

# %%
mask, prob =  output[0]["artilife"]
for m,p in zip(mask,prob):
    plt.imshow(m);plt.show()
    plt.imshow(p);plt.show()

# %%
cellData = output[1]
cellData
# Out:
#       Cell  Birth  Death                                          Sizes
# 0      1.0      0      8  [401, 393, 401, 398, 397, 398, 399, 412, 408]
# 1      2.0      0      8    [47, 79, 104, 136, 159, 184, 211, 230, 261]
# 2      3.0      0      8  [274, 279, 282, 293, 283, 290, 299, 301, 303]
# 3      4.0      0      8  [364, 364, 359, 348, 342, 347, 359, 359, 361]
# 4      5.0      0      8  [295, 306, 294, 302, 309, 320, 330, 343, 347]
# ..     ...    ...    ...                                            ...
# 131  132.0      8      8                   [0, 0, 0, 0, 0, 0, 0, 0, 40]
# 132  133.0      8      8                   [0, 0, 0, 0, 0, 0, 0, 0, 57]
# 133  134.0      7      8                  [0, 0, 0, 0, 0, 0, 0, 15, 46]
# 134  135.0      8      8                   [0, 0, 0, 0, 0, 0, 0, 0, 29]
# 135  136.0      6      8               [0, 0, 0, 0, 0, 0, 13, 138, 103]
#
# [136 rows x 4 columns]

# %%
for mask, probMask in zip(masks, probability):
    plt.imshow(mask);plt.show()
    plt.imshow(probMask);plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/berk/code/budNET_gui/budSeg.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/berk/code/budNET_gui/budSeg.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> for mask, probMask in zip(masks, probability):
#       <a href='vscode-notebook-cell:/Users/berk/code/budNET_gui/budSeg.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a>     plt.imshow(mask);plt.show()
#       <a href='vscode-notebook-cell:/Users/berk/code/budNET_gui/budSeg.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a>     plt.imshow(probMask);plt.show()
#
# NameError: name 'masks' is not defined

# %%
test_im_resized = resize(test_im[0,:,:], (160,160))
test_im_resized = merge((test_im_resized,test_im_resized,test_im_resized))
test_im_resized.shape

# %%
BudSeg.prediction(test_im_resized)

# %%
def produce_bbox(r,c,im, size = 160):

# %%
regions = regionprops(art_seg[0,:,:])
for region in regions:
    print(region.centroid)
